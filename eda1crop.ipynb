# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("crop_yield.csv")
df
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...

# %%
df.shape
# Out:
# (19689, 10)

# %%
### univariate analysis on numeric columns

# %%
df.head()
# Out:
#            Crop  Crop_Year       Season  State     Area  Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield
# 0           2051.4  7024878.38   22882.34     0.796087
# 1           2051.4   631643.29    2057.47     0.710435
# 2           2051.4    75755.32     246.76     0.238333
# 3           2051.4  1870661.52    6093.36  5238.051739
# 4           2051.4   165500.63     539.09     0.420909

# %%
### we have seven numerical columns

# %%
### Crop_Year

# %%
### conclusions- 
# Crop_Year is normally distributed
#there are no out;iers
# no missing values

# %%
df['Crop_Year'].describe()
# Out:
# count    19689.000000
# mean      2009.127584
# std          6.498099
# min       1997.000000
# 25%       2004.000000
# 50%       2010.000000
# 75%       2015.000000
# max       2020.000000
# Name: Crop_Year, dtype: float64

# %%
df['Crop_Year'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Crop_Year'].plot(kind='kde',)
# Out:
# <Axes: ylabel='Density'>

# %%
df['Crop_Year'].skew()
# Out:
# np.float64(-0.16265562121556904)

# %%
df['Crop_Year'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Crop_Year']>2005]
# Out:
#                Crop  Crop_Year       Season       State     Area  Production  \
# 1949       Arecanut       2006  Kharif       Puducherry     63.0          82
# 1950       Arecanut       2006  Whole Year   Puducherry     63.0          82
# 1951         Banana       2006  Kharif       Puducherry    305.0        9890
# 1952   Black pepper       2006  Kharif       Puducherry     12.0           7
# 1953   Cotton(lint)       2006  Summer       Puducherry     57.0          40
# ...             ...        ...          ...         ...      ...         ...
# 19676     Sugarcane       2018  Winter           Odisha   6778.0      417672
# 19677          Urad       2018  Autumn           Odisha  13720.0        3583
# 19678          Urad       2018  Summer           Odisha   4571.0        2336
# 19679          Urad       2018  Winter           Odisha  39560.0       13123
# 19680         Wheat       2018  Summer           Odisha    147.0         268
#
# ...

# %%
df['Crop_Year'].isnull().sum()
# Out:
# np.int64(0)

# %%
### Area

# %%
### conclusions
# the data is highly(positively)skewed
#there is no nujll values

# %%
df['Area'].describe()
# Out:
# count    1.968900e+04
# mean     1.799266e+05
# std      7.328287e+05
# min      5.000000e-01
# 25%      1.390000e+03
# 50%      9.317000e+03
# 75%      7.511200e+04
# max      5.080810e+07
# Name: Area, dtype: float64

# %%
df['Area'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Area'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Area'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Area']<1000]
# Out:
#               Crop  Crop_Year       Season      State   Area  Production  \
# 2      Castor seed       1997  Kharif           Assam  796.0          22
# 24         Tobacco       1997  Whole Year       Assam  433.0          26
# 30           Bajra       1997  Summer       Karnataka  820.0         662
# 63       Arhar/Tur       1997  Kharif       Meghalaya  865.0         683
# 65     Castor seed       1997  Rabi         Meghalaya   30.0          15
# ...            ...        ...          ...        ...    ...         ...
# 19655   Horse-gram       2018  Summer          Odisha   38.0          14
# 19657         Jute       2018  Autumn          Odisha  200.0         313
# 19660        Maize       2018  Winter          Odisha   67.0         164
# 19667         Ragi       2018  Summer          Odisha  212.0         132
# 19680        Wheat       2018  Summer          Odisha  147.0         268
#
#        Annual_Rainfall  Fertilizer  Pesticide     Yield
# ...

# %%
df['Area'].skew()
# Out:
# np.float64(21.858217797355426)

# %%
df['Area'].isnull().sum()
# Out:
# np.int64(0)

# %%
###Production

# %%
### Conclusions 
'''-Most values are small, but a few very large ones create outliers.

    -The distribution is right-skewed (long tail on higher side).

    Zeros in the data may indicate missing or invalid entries.

    The mean is misleading due to outliers; median is a better measure.

    Log transformation reduces skewness and makes the data more balanced'''
# Out:
# '-Most values are small, but a few very large ones create outliers.\n\n    -The distribution is right-skewed (long tail on higher side).\n\n    Zeros in the data may indicate missing or invalid entries.\n\n    The mean is misleading due to outliers; median is a better measure.\n\n    Log transformation reduces skewness and makes the data more balanced'

# %%
df['Production'].describe()
# Out:
# count    1.968900e+04
# mean     1.643594e+07
# std      2.630568e+08
# min      0.000000e+00
# 25%      1.393000e+03
# 50%      1.380400e+04
# 75%      1.227180e+05
# max      6.326000e+09
# Name: Production, dtype: float64

# %%
df['Production'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Production"].plot(kind = "kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df["log_Production"] = np.log1p(df["Production"])

# %%
df["log_Production"].plot(kind= 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["log_Production"].plot(kind= 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df["Production"].skew()
# Out:
# np.float64(19.299193411606723)

# %%
df["log_Production"].skew()
# Out:
# np.float64(0.003417531796101991)

# %%
df['Production'].isnull().sum()
# Out:
# np.int64(0)

# %%
### Annual_Rainfall

# %%
# conclusions
'''Distribution – Slightly right-skewed, meaning a few very high rainfall values.

Outliers – High kurtosis indicates extreme rainfall years

Missing Data – No null values (clean data).

Variety – Many unique rainfall values dataset is detailed.
# Out:
#   Cell In[37], line 2
#     '''Distribution – Slightly right-skewed, meaning a few very high rainfall values.
#     ^
# _IncompleteInputError: incomplete input

# %%
df["Annual_Rainfall"]
# Out:
# 0        2051.4
# 1        2051.4
# 2        2051.4
# 3        2051.4
# 4        2051.4
#           ...
# 19684    1498.0
# 19685    1498.0
# 19686    1356.2
# 19687    1356.2
# 19688    1356.2
# Name: Annual_Rainfall, Length: 19689, dtype: float64

# %%
df["Annual_Rainfall"].describe()
# Out:
# count    19689.000000
# mean      1437.755177
# std        816.909589
# min        301.300000
# 25%        940.700000
# 50%       1247.600000
# 75%       1643.700000
# max       6552.700000
# Name: Annual_Rainfall, dtype: float64

# %%
df["Annual_Rainfall"].plot(kind="hist",bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Annual_Rainfall"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df["Annual_Rainfall"].skew()
# Out:
# np.float64(2.131785011464436)

# %%
df["Annual_Rainfall"].nunique()
# Out:
# 634

# %%
df["Annual_Rainfall"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Annual_Rainfall"].plot(kind = "box")
# Out:
# <Axes: >

# %%
df["Annual_Rainfall"].kurt()
# Out:
# np.float64(6.97498304618661)

# %%
# Fertilizer

# %%
# Conclusions
'''Values range from 54 to 4.8B, indicating extreme variation.

Data is right-skewed with a few very large outliers.

No null values data is clean 

After applying log, the data looks more balanced.

# %%
df["Fertilizer"]
# Out:
# 0         7024878.38
# 1          631643.29
# 2           75755.32
# 3         1870661.52
# 4          165500.63
#             ...
# 19684      395200.00
# 19685       98800.00
# 19686    29586735.11
# 19687    26242746.82
# 19688    22778368.48
# Name: Fertilizer, Length: 19689, dtype: float64

# %%
df["Fertilizer"].describe()
# Out:
# count    1.968900e+04
# mean     2.410331e+07
# std      9.494600e+07
# min      5.417000e+01
# 25%      1.880146e+05
# 50%      1.234957e+06
# 75%      1.000385e+07
# max      4.835407e+09
# Name: Fertilizer, dtype: float64

# %%
df["Fertilizer"].plot(kind="hist", bins=30, figsize=(7,5), edgecolor="red")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Fertilizer"].plot(kind="box", figsize=(6,4))
# Out:
# <Axes: >

# %%
df["Fertilizer"].plot(kind="kde", figsize=(7,5))
# Out:
# <Axes: ylabel='Density'>

# %%
df["Fertilizer"].apply(lambda x: np.log1p(x)).plot(kind="hist", bins=30, figsize=(7,5), edgecolor="black")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Fertilizer"].skew()
# Out:
# np.float64(13.412598810025761)

# %%
df["Fertilizer"].nunique()
# Out:
# 18598

# %%
df["Fertilizer"].isnull().sum()
# Out:
# np.int64(0)

# %%
### Pesticide

# %%
# Pesticide
'''The distribution is right-skewed, with clear outliers.

No null values the data is clean.

After log transformation, the data looks more balanced

# %%
df["Pesticide"]
# Out:
# 0        22882.34
# 1         2057.47
# 2          246.76
# 3         6093.36
# 4          539.09
#            ...
# 19684     1160.00
# 19685      290.00
# 19686    96373.73
# 19687    85481.26
# 19688    74196.64
# Name: Pesticide, Length: 19689, dtype: float64

# %%
df["Pesticide"].describe()
# Out:
# count    1.968900e+04
# mean     4.884835e+04
# std      2.132874e+05
# min      9.000000e-02
# 25%      3.567000e+02
# 50%      2.421900e+03
# 75%      2.004170e+04
# max      1.575051e+07
# Name: Pesticide, dtype: float64

# %%
df["Pesticide"].plot(kind="hist", bins=30, figsize=(7,5), edgecolor="black", title="Pesticide Distribution")
# Out:
# <Axes: title={'center': 'Pesticide Distribution'}, ylabel='Frequency'>

# %%
df["Pesticide"].plot(kind="box", figsize=(6,4), title="Pesticide Boxplot")
# Out:
# <Axes: title={'center': 'Pesticide Boxplot'}>

# %%
df["Pesticide"].plot(kind="kde", figsize=(7,5), title="Pesticide Density Plot")
# Out:
# <Axes: title={'center': 'Pesticide Density Plot'}, ylabel='Density'>

# %%
df["Pesticide"].apply(lambda x: np.log1p(x)).plot(kind="hist", bins=30, figsize=(7,5), edgecolor="black", title="Log-Transformed Pesticide Distribution")
# Out:
# <Axes: title={'center': 'Log-Transformed Pesticide Distribution'}, ylabel='Frequency'>

# %%
df["Pesticide"].skew()
# Out:
# np.float64(25.635746086843607)

# %%
df["Pesticide"].nunique()
# Out:
# 17405

# %%
df["Pesticide"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["Pesticide"].kurt()
# Out:
# np.float64(1546.7276228094033)

# %%
df["Pesticide"].apply(lambda x: np.log1p(x)).plot(kind="kde", figsize=(7,5), title="Log-Transformed Pesticide Distribution")
# Out:
# <Axes: title={'center': 'Log-Transformed Pesticide Distribution'}, ylabel='Density'>

# %%
df.head()
# Out:
#            Crop  Crop_Year       Season  State     Area  Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield  log_Production
# 0           2051.4  7024878.38   22882.34     0.796087       10.945688
# 1           2051.4   631643.29    2057.47     0.710435        8.452335
# 2           2051.4    75755.32     246.76     0.238333        3.135494
# 3           2051.4  1870661.52    6093.36  5238.051739       18.658949
# 4           2051.4   165500.63     539.09     0.420909        6.678342

# %%
### Yield

# %%
# Conclusions
'''Yield data is highly right-skewed.

Most records show very small yields (0–2.5).

No null values data is complete.

After log scaling, the data looks more balanced

# %%
df["Yield"]
# Out:
# 0           0.796087
# 1           0.710435
# 2           0.238333
# 3        5238.051739
# 4           0.420909
#             ...
# 19684       0.500000
# 19685       3.000000
# 19686       1.285000
# 19687       0.016667
# 19688       1.261818
# Name: Yield, Length: 19689, dtype: float64

# %%
df["Yield"].describe()
# Out:
# count    19689.000000
# mean        79.954009
# std        878.306193
# min          0.000000
# 25%          0.600000
# 50%          1.030000
# 75%          2.388889
# max      21105.000000
# Name: Yield, dtype: float64

# %%
df["Yield"].plot(kind="hist", bins=30, figsize=(7,5), edgecolor="pink", title="Yield Distribution")
# Out:
# <Axes: title={'center': 'Yield Distribution'}, ylabel='Frequency'>

# %%
df["Yield"].plot(kind="box", figsize=(6,4), title="Yield Boxplot")
# Out:
# <Axes: title={'center': 'Yield Boxplot'}>

# %%
df["Yield"].plot(kind="kde", figsize=(7,5), title="Yield Density Plot")
# Out:
# <Axes: title={'center': 'Yield Density Plot'}, ylabel='Density'>

# %%
df["Yield"].apply(lambda x: np.log1p(x)).plot(kind="hist", bins=30, figsize=(7,5), edgecolor="black", title="Log-Transformed Yield Distribution")
# Out:
# <Axes: title={'center': 'Log-Transformed Yield Distribution'}, ylabel='Frequency'>

# %%
df["Yield"].apply(lambda x: np.log1p(x)).plot(kind="kde", figsize=(7,5), title="Log-Transformed Yield Distribution")
# Out:
# <Axes: title={'center': 'Log-Transformed Yield Distribution'}, ylabel='Density'>

# %%
 df["Yield"].skew()
# Out:
# np.float64(12.785264685628688)

# %%
 df["Yield"].isnull().sum()
# Out:
# np.int64(0)

# %%
 df["Yield"].nunique()
# Out:
# 13551

# %%
### Univariate analysis on categorical columns

# %%
df.head()
# Out:
#            Crop  Crop_Year       Season  State     Area  Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield  log_Production
# 0           2051.4  7024878.38   22882.34     0.796087       10.945688
# 1           2051.4   631643.29    2057.47     0.710435        8.452335
# 2           2051.4    75755.32     246.76     0.238333        3.135494
# 3           2051.4  1870661.52    6093.36  5238.051739       18.658949
# 4           2051.4   165500.63     539.09     0.420909        6.678342

# %%
# crop

# %%
# Conclusion

-Rice is the most used crop with the highest production.

-Other cereals and pulses like Summer Pulses, Guar seed, Khesari are produced very little.

-The dataset is skewed towards a few high-yield crops (Rice, Maize, Potato, Sugarcane) while many crops are produced in smaller amounts

-Crops like Rice and Maize are extreme outliers compared to most others

# %%
df["Crop"].value_counts()
# Out:
# Crop
# Rice                     1197
# Maize                     975
# Moong(Green Gram)         740
# Urad                      733
# Groundnut                 725
# Sesamum                   685
# Potato                    628
# Sugarcane                 605
# Wheat                     545
# Rapeseed &Mustard         528
# Bajra                     524
# Jowar                     513
# Arhar/Tur                 508
# Ragi                      498
# Gram                      490
# Small millets             485
# Cotton(lint)              476
# Onion                     454
# Sunflower                 441
# Dry chillies              419
# Other Kharif pulses       382
# Horse-gram                371
# Peas & beans (Pulses)     369
# Tobacco                   364
# Other  Rabi pulses        355
# Soyabean                  349
# Turmeric                  337
# Masoor                    324
# Ginger                    323
# Linseed                   308
# Castor seed               300
# ...

# %%
df["Crop"].value_counts().plot(kind="bar", figsize=(13,20), title="crop type analysis", edgecolor="green")
# Out:
# <Axes: title={'center': 'crop type analysis'}, xlabel='Crop'>

# %%
df["Crop"].value_counts().head(10).plot(kind="bar", title="Top 10 Crop Type Analysis", figsize=(7,5))
# Out:
# <Axes: title={'center': 'Top 10 Crop Type Analysis'}, xlabel='Crop'>

# %%
df["Crop"].value_counts().plot(kind="pie", title="crop type analysis" , autopct="%1.1f%%",figsize=(15,15))
# Out:
# <Axes: title={'center': 'crop type analysis'}, ylabel='count'>

# %%
df.head()
# Out:
#            Crop  Crop_Year       Season  State     Area  Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield  log_Production
# 0           2051.4  7024878.38   22882.34     0.796087       10.945688
# 1           2051.4   631643.29    2057.47     0.710435        8.452335
# 2           2051.4    75755.32     246.76     0.238333        3.135494
# 3           2051.4  1870661.52    6093.36  5238.051739       18.658949
# 4           2051.4   165500.63     539.09     0.420909        6.678342

# %%
df["Crop"].value_counts().head(10).plot(kind="pie", title="Top 10 Crop Type Analysis", autopct="%1.1f%%", figsize=(7,5))
# Out:
# <Axes: title={'center': 'Top 10 Crop Type Analysis'}, ylabel='count'>

# %%
df["Crop"].value_counts().plot(kind="box", figsize=(7,5), title="box plot of crop type")
# Out:
# <Axes: title={'center': 'box plot of crop type'}>

# %%
df.copy()
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...

# %%
### Season

# %%
# Conclusion
'''The dataset has 3 main seasons: Kharif, Rabi, Whole Year
upper case issues might appear if some rows have rabi or Rabi'''
# Out:
# 'The dataset has 3 main seasons: Kharif, Rabi, Whole Year\nupper case issues might appear if some rows have rabi or Rabi'

# %%
df["Season"]
# Out:
# 0        Whole Year
# 1        Kharif
# 2        Kharif
# 3        Whole Year
# 4        Kharif
#             ...
# 19684    Kharif
# 19685    Rabi
# 19686    Kharif
# 19687    Kharif
# 19688    Rabi
# Name: Season, Length: 19689, dtype: object

# %%
df["Season"].value_counts()
# Out:
# Season
# Kharif         8232
# Rabi           5742
# Whole Year     3717
# Summer         1195
# Autumn          414
# Winter          389
# Name: count, dtype: int64

# %%
df["Season"].value_counts().sum()
# Out:
# np.int64(19689)

# %%
df["Season"].value_counts().plot(kind="bar", figsize=(7,5), title="Seasons", edgecolor="green")
# Out:
# <Axes: title={'center': 'Seasons'}, xlabel='Season'>

# %%
df["Season"].value_counts().plot(kind="pie", title="seasons" , autopct="%1.1f%%",figsize=(7,5))
# Out:
# <Axes: title={'center': 'seasons'}, ylabel='count'>

# %%
df["Season"].value_counts().plot(kind="box", title="seasons")
# Out:
# <Axes: title={'center': 'seasons'}>

# %%
### state

# %%
# Conclusions
'''Karnataka, Andhra Pradesh, and West Bengal have the most crop records, meaning they dominate in agricultural entries.

States like Delhi, Sikkim, and Goa have very few records

Some states (like Karnataka) have thousands of records, while others (like Delhi) have very few.

# %%
df["State"]
# Out:
# 0                    Assam
# 1                    Assam
# 2                    Assam
# 3                    Assam
# 4                    Assam
#                ...
# 19684             Nagaland
# 19685             Nagaland
# 19686    Jammu and Kashmir
# 19687    Jammu and Kashmir
# 19688    Jammu and Kashmir
# Name: State, Length: 19689, dtype: object

# %%
df["State"].value_counts()
# Out:
# State
# Karnataka            1432
# Andhra Pradesh       1266
# West Bengal          1094
# Chhattisgarh          915
# Bihar                 896
# Madhya Pradesh        845
# Uttar Pradesh         825
# Tamil Nadu            822
# Gujarat               817
# Maharashtra           770
# Uttarakhand           764
# Odisha                760
# Assam                 731
# Nagaland              689
# Puducherry            670
# Meghalaya             649
# Haryana               631
# Jammu and Kashmir     631
# Himachal Pradesh      616
# Kerala                534
# Manipur               444
# Tripura               441
# Mizoram               416
# Telangana             397
# Punjab                397
# Arunachal Pradesh     292
# Jharkhand             270
# Goa                   246
# Sikkim                226
# Delhi                 203
# Name: count, dtype: int64

# %%
df["State"].value_counts().plot(kind="bar",title = "states wise analysis", figsize=(7,5), edgecolor = "black")
# Out:
# <Axes: title={'center': 'states wise analysis'}, xlabel='State'>

# %%
df["State"].value_counts().head(10).plot(kind="pie", title="States" , autopct="%1.1f%%",figsize=(7,5))

# %%
df["State"].value_counts().head(10).plot(kind="bar", title="State wise analysis" ,figsize=(7,5))
# Out:
# <Axes: title={'center': 'State wise analysis'}, xlabel='State'>

# %%
df["State"].value_counts().head(10).plot(kind="pie", title="State wise analysis" , autopct="%1.1f%%",figsize=(7,5))
# Out:
# <Axes: title={'center': 'State wise analysis'}, ylabel='count'>

# %%
df["State"].value_counts().plot(kind="box", title="state wise analysis")
# Out:
# <Axes: title={'center': 'state wise analysis'}>

# %%
### Steps of doing Bivariate Analysis

'''- Select 2 cols
- Understand type of relationship
    1. **Numerical - Numerical**<br>
        a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>
        b. Check correlation coefficent to check linear relationship
        
    2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
        a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots<br>
        
    3. **Categorical - Categorical**<br>
        a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
        b. You can plots like heatmap, stacked barplots, treemaps
        
- Write your conclusions'''
# Out:
# '- Select 2 cols\n- Understand type of relationship\n    1. **Numerical - Numerical**<br>\n        a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>\n        b. Check correlation coefficent to check linear relationship\n\n    2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>\n        a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots<br>\n\n    3. **Categorical - Categorical**<br>\n        a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>\n        b. You can plots like heatmap, stacked barplots, treemaps\n\n- Write your conclusions'

# %%
df.copy()
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield
# ...

# %%
# Remove spaces from column names first (just in case)
df.columns = df.columns.str.strip()

# Convert Area and Yield columns to numeric
df['Area'] = pd.to_numeric(df['Area'], errors='coerce')
df['Yield'] = pd.to_numeric(df['Yield'], errors='coerce')

# %%
df[['Yield', 'Area']].corr()
# Out:
#           Yield      Area
# Yield  1.000000  0.001858
# Area   0.001858  1.000000

# %%
df['Production'] = pd.to_numeric(df['Production'], errors='coerce')
df['Fertilizer'] = pd.to_numeric(df['Fertilizer'], errors='coerce')
df['Pesticide'] = pd.to_numeric(df['Area'], errors='coerce')
df['annual_Rainfall'] = pd.to_numeric(df['Annual_Rainfall'], errors='coerce')

# %%
df[['Yield', 'Area']].
# Out:
#             Yield        Area
# Yield  100.000000    0.185848
# Area     0.185848  100.000000

# %%
sns.heatmap(df[['Yield', 'Area']].corr())
# Out:
# <Axes: >

# %%
sns.scatterplot(df[['Yield', 'Area']].corr())
# Out:
# <Axes: >

# %%
sns.jointplot(x="Area", y="Yield", data=df, kind="scatter")

# %%
### conclusions
''' Heatmap shows 0.19% correlation (almost zero).
Cultivated area does not directly affect yield.

# %%
### season and yield

# %%
mean_yield=df.groupby("Season")["Yield"].mean()
mean_yield
# Out:
# Season
# Autumn           3.917482
# Kharif           2.482002
# Rabi             1.988518
# Summer           2.997370
# Whole Year     412.995463
# Winter           5.287267
# Name: Yield, dtype: float64

# %%
df["log_Yield"] = np.log1p(df["Yield"])
sns.kdeplot(data=df, x="log_Yield", hue="Season", fill=True)
# Out:
# <Axes: xlabel='log_Yield', ylabel='Density'>

# %%
sns.boxplot(data=df, x="log_Yield", hue="Season", fill=True)
# Out:
# <Axes: xlabel='log_Yield'>

# %%
## conclusions
'''
Whole Year season shows much higher yield values than all others.

Kharif, Rabi, Summer, Autumn, and Winter yields are in lower ranges with smaller spread

Log transformation balanced the distribution and made seasonal comparisons possible.

# %%
## pesticide and area

# %%
df[['Pesticide', 'Area']].corr()
# Out:
#            Pesticide  Area
# Pesticide        1.0   1.0
# Area             1.0   1.0

# %%
sns.heatmap(df[['Pesticide', 'Area']].corr()*100)
# Out:
# <Axes: >

# %%
### conclusion
'''
whenever Area increases, Pesticide increases in exact proportion

dataset has no variability between these two columns

No real-world scenario

# %%
### Crop vs Yield

# %%
df["log_Yield"] = np.log1p(df["Yield"])

sns.kdeplot(data=df, x="log_Yield", hue="Crop", fill=True)
# Out:
# <Axes: xlabel='log_Yield', ylabel='Density'>

# %%
sns.boxplot(data=df, x="Crop", y="Yield")
# Out:
# <Axes: xlabel='Crop', ylabel='Yield'>

# %%
df
# Out:
#                 Crop  Crop_Year       Season              State      Area  \
# 0           Arecanut       1997  Whole Year               Assam   73814.0
# 1          Arhar/Tur       1997  Kharif                   Assam    6637.0
# 2        Castor seed       1997  Kharif                   Assam     796.0
# 3           Coconut        1997  Whole Year               Assam   19656.0
# 4       Cotton(lint)       1997  Kharif                   Assam    1739.0
# ...              ...        ...          ...                ...       ...
# 19684  Small millets       1998  Kharif                Nagaland    4000.0
# 19685          Wheat       1998  Rabi                  Nagaland    1000.0
# 19686          Maize       1997  Kharif       Jammu and Kashmir  310883.0
# 19687           Rice       1997  Kharif       Jammu and Kashmir  275746.0
# 19688          Wheat       1997  Rabi         Jammu and Kashmir  239344.0
#
#        Production  Annual_Rainfall   Fertilizer  Pesticide        Yield  \
# ...

# %%
## Conclusions

# %%
### production and yield

# %%
df[['Production', 'log_Yield']].corr()
# Out:
#             Production  log_Yield
# Production    1.000000   0.419581
# log_Yield     0.419581   1.000000

# %%
sns.heatmap(df[['Production', 'log_Yield']].corr())
# Out:
# <Axes: >

# %%
sns.jointplot(data=df, x="log_Yield", y="Production", kind="scatter")

# %%
##conclusion 
'''
Production and log_Yield show a moderate positive relation higher production generally means higher log_Yield.

# %%
### crop and season

# %%
pd.crosstab(df["Season"], df["Crop"])
# Out:
# Crop         Arecanut  Arhar/Tur  Bajra  Banana  Barley  Black pepper  \
# Season
# Autumn              0          1      0       1       0             0
# Kharif             20        418    389      32      47            13
# Rabi               16         69     58       1     248             6
# Summer              0          1     52      13       0             0
# Whole Year        126         16     25     197       2           107
# Winter              0          3      0       1       0             0
#
# Crop         Cardamom  Cashewnut  Castor seed  Coconut   ...  Soyabean  \
# Season                                                   ...
# Autumn              0          0            0         0  ...         1
# Kharif              3         27          255         2  ...       326
# Rabi                0          5           36         0  ...        16
# Summer              0          0            0         0  ...         0
# ...

# %%
sns.heatmap(pd.crosstab(df["Season"], df["Crop"]))
# Out:
# <Axes: xlabel='Crop', ylabel='Season'>

# %%
sns.countplot(data=df, x="Season", hue="Crop")
plt.title("Season vs Crop")

plt.show()

# %%
### conclusions 
'''
Whole Year crops like Sugarcane, Coconut, and Arecanut are grown consistently across all months.

Kharif season shows the highest variety and frequency of crops

Overall, Kharif and Rabi are the primary crop-growing seasons
